# %% [markdown]
# **ФИО**:

# %% [markdown]
# # Задание (совместное с преподавателем)

# %% [markdown]
# Напишите систему для учёта отпусков с возможностью узнавать, сколько дней отпуска осталось у того или иного сотрудника.
# Для этого создайте класс Employee со следующими методами:
#
# - Метод consume_vacation должен отвечать за списание дней отпуска.
#
# Единственный параметр этого метода (кроме self) — количество потраченных отпускных дней (целое число).
#
# При вызове метода consume_vacation соответствующее количество дней должно вычитаться из общего числа доступных отпускных дней сотрудника.
#
# Чтобы определить число доступных отпускных дней конкретного сотрудника, в классе опишите атрибут экземпляра |, который по умолчанию будет равен значению атрибута класса vacation_days, и используйте этот атрибут в работе метода.
#
# - Метод get_vacation_details должен возвращать остаток отпускных дней сотрудника в формате: ```Остаток отпускных дней: <число>.```
#
#
# Чтобы проверить работу программы:
# 1. Создайте экземпляр класса Employee.
# 2. Вызовите метод consume_vacation, указав подходящее значение аргумента, например 7.
# 3. Вызовите метод get_vacation_details.

# %%
class Employee:
    vacation_days = 28


    def __init__(self):
        self.available_vacation_days = Employee.vacation_days


    def consume_vacation(self, days):
        if days < 0:
            print("Количество дней не может быть отрицательным.")
            return
        if days > self.available_vacation_days:
            print("Недостаточно доступных отпускных дней.")
            return
        self.available_vacation_days -= days


    def get_vacation_details(self):
        return f"Остаток отпускных дней: {self.available_vacation_days}"

# Пример использования
employee = Employee()
print(employee.get_vacation_details())

employee.consume_vacation(7)
print(employee.get_vacation_details())
# Out:
# Остаток отпускных дней: 28
# Остаток отпускных дней: 21

# %% [markdown]
# # Задание 1

# %% [markdown]
# Задание:
#
# Создайте класс с именем Rectangle который имеет:
# - Атрибуты ширины и высоты.
# - Метод расчета площади.
# - Метод расчета периметра.
# - Метод отображения размеров прямоугольника.
#
# Создайте экземпляр класса Rectangleи продемонстрируйте его функциональность.

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height


    def area(self):
        return self.width * self.height


    def perimeter(self):
        return 2 * (self.width + self.height)


    def display(self):
        return f"Ширина: {self.width}, Высота: {self.height}"

# Создание экземпляра класса
rect = Rectangle(5, 10)

# Демонстрация функциональности
print(rect.display())
print(f"Площадь: {rect.area()}")
print(f"Периметр: {rect.perimeter()}")
# Out:
# Ширина: 5, Высота: 10
# Площадь: 50
# Периметр: 30

# %% [markdown]
# # Задание 2

# %% [markdown]
# Задание: Создайте мини версию банковской системы:
#
#
# Инструкции:
#
# 1. Создайте класс BankAccountсо следующими атрибутами:
#     - account_holder -  владелец счета
#     - balance - баланс счета
#
# 2. Реализуйте следующие методы:
#     - Метод для инициализации владельца счета: имя владельца счета и установите начальный баланс на 0.
#     - deposit(amount): Добавьте указанную сумму к балансу.
#     - withdraw(amount): Вычесть указанную сумму из баланса, если средств достаточно; в противном случае вывести предупреждение.
#     - get_balance(): Возврат текущего баланса.
#
#
# Создайте объект класса и продемонстрируйте его возможности

# %%
class BankAccount:
    def __init__(self, account_holder):
        self.account_holder = account_holder
        self.balance = 0


    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"На счет {self.account_holder} внесено {amount}. Текущий баланс: {self.balance}.")
        else:
            print("Сумма депозита должна быть положительной.")


    def withdraw(self, amount):
        if amount > self.balance:
            print(f"Предупреждение: недостаточно средств для снятия {amount}. Текущий баланс: {self.balance}.")
        elif amount <= 0:
            print("Сумма снятия должна быть положительной.")
        else:
            self.balance -= amount
            print(f"Со счета {self.account_holder} снято {amount}. Текущий баланс: {self.balance}.")


    def get_balance(self):
        return self.balance

# Пример использования
account = BankAccount("Иван Иванов")
account.deposit(1000)
account.withdraw(500)
print(f"Текущий баланс: {account.get_balance()}.")
account.withdraw(700)
# Out:
# На счет Иван Иванов внесено 1000. Текущий баланс: 1000.
# Со счета Иван Иванов снято 500. Текущий баланс: 500.
# Текущий баланс: 500.
# Предупреждение: недостаточно средств для снятия 700. Текущий баланс: 500.

# %% [markdown]
# # Задание 3

# %% [markdown]
# Возьмите код и задание (Рыцарь и дракон) из предыдущей практики и реализуйте его с применением классов

# %%
import random

class Knight:
    def __init__(self, name, armor, weapon):
        self.name = name
        self.armor = armor
        self.weapon = weapon
        self.damage = random.randint(10, 20)
        self.health = 100


    def attack(self, dragon):
        dragon_damage = random.randint(0, self.damage)
        dragon.health -= dragon_damage
        print(f"{self.name} наносит {dragon_damage} урона {dragon.name}! Здоровье дракона: {dragon.health}")


class Dragon:
    def __init__(self):
        self.name = "Дракон"
        self.health = 80
        self.damage = random.randint(5, 15)


    def attack(self, knight):
        knight_damage = random.randint(0, self.damage)
        knight.health -= knight_damage
        print(f"{self.name} наносит {knight_damage} урона {knight.name}! Здоровье рыцаря: {knight.health}")


class Game:
    def __init__(self):
        self.knight = None
        self.dragon = Dragon()


    def create_knight(self):
        name = input("Введите имя вашего рыцаря: ")
        armor = input("Введите информацию о доспехах: ")
        weapon = input("Введите название оружия: ")
        self.knight = Knight(name, armor, weapon)


    def battle(self):
        print(f"Начинается бой между {self.knight.name} и {self.dragon.name}!")

        while self.knight.health > 0 and self.dragon.health > 0:
            print("Выберите действие:")
            print("1. Атаковать")
            print("2. Защититься")
            print("3. Использовать предмет (восстановить здоровье)")
            action = input("Выберите действие (1-3): ")

            if action == '1':
                self.knight.attack(self.dragon)
                if self.dragon.health <= 0:
                    print(f"{self.dragon.name} повержен! {self.knight.name} победил!")
                    break

            elif action == '2':
                print(f"{self.knight.name} готовится к защите!")
                knight_damage = random.randint(0, self.dragon.damage // 2)
                self.knight.health -= knight_damage
                print(f"{self.dragon.name} наносит {knight_damage} урона {self.knight.name}! Здоровье рыцаря: {self.knight.health}")

            elif action == '3':
                heal_amount = random.randint(10, 30)
                self.knight.health += heal_amount
                print(f"{self.knight.name} использует предмет и восстанавливает {heal_amount} здоровья! Здоровье рыцаря: {self.knight.health}")

            else:
                print("Неверный выбор, попробуйте снова.")
                continue

            if action != '2':
                self.dragon.attack(self.knight)

            if self.knight.health <= 0:
                print(f"{self.knight.name} пал в бою! {self.dragon.name} победил!")
                break


def main():
    print("Добро пожаловать в игру 'Рыцарь и дракон'!")
    game = Game()
    game.create_knight()
    game.battle()


if __name__ == "__main__":
    main()
# Out:
# Добро пожаловать в игру 'Рыцарь и дракон'!
# Введите имя вашего рыцаря: Павел
# Введите информацию о доспехах: 70
# Введите название оружия: Меч
# Начинается бой между Павел и Дракон!
# Выберите действие:
# 1. Атаковать
# 2. Защититься
# 3. Использовать предмет (восстановить здоровье)
# Выберите действие (1-3): 1
# Павел наносит 3 урона Дракон! Здоровье дракона: 77
# Дракон наносит 4 урона Павел! Здоровье рыцаря: 96
# Выберите действие:
# 1. Атаковать
# 2. Защититься
# 3. Использовать предмет (восстановить здоровье)
# Выберите действие (1-3): 1
# Павел наносит 3 урона Дракон! Здоровье дракона: 74
# Дракон наносит 15 урона Павел! Здоровье рыцаря: 81
# Выберите действие:
# 1. Атаковать
# 2. Защититься
# 3. Использовать предмет (восстановить здоровье)
# Выберите действие (1-3): 1
# Павел наносит 6 урона Дракон! Здоровье дракона: 68
# Дракон наносит 15 урона Павел! Здоровье рыцаря: 66
# Выберите действие:
# 1. Атаковать
# 2. Защититься
# 3. Использовать предмет (восстановить здоровье)
# ...

# %% [markdown]
# # Дополнительное задание

# %% [markdown]
# Задача: Система управления библиотекой
#
# **Цель**
# Создайте простую систему управления библиотекой, которая позволит пользователям добавлять книги, брать книги, возвращать книги и просматривать список доступных книг.
#
# **Требования**
#
# 1. **Определение класса**:
#    – Создайте класс с именем «Book» со следующими атрибутами:
#      - `title`
#      - `автор`
#      - `isbn`
#      - `is_borrowed` (по умолчанию `False`)
#
# 2. **Класс библиотеки**:
#    - Создайте класс с именем Library, который управляет коллекцией книг.
#    - Класс должен иметь следующие методы:
#      - `__init__(self)`: инициализирует пустой список книг.
#      - `add_book(self, book: Book)`: добавляет новую книгу в библиотеку.
#      - `borrow_book(self, isbn: str)`: помечает книгу как заимствованную. Если книга не найдена или уже взята, выведите соответствующее сообщение.
#      - `return_book(self, isbn: str)`: помечает книгу как возвращенную. Если книга не найдена или не была взята взаймы, выведите соответствующее сообщение.
#      - `list_available_books(self)`: печатает список всех доступных книг в библиотеке.
#      - `find_book(self, isbn: str)`: возвращает объект книги, если он найден, в противном случае возвращает `None`.
#
# 3. **Взаимодействие с пользователем**:
#    - Создайте простое текстовое меню, которое позволит пользователям:
#      - Добавить книгу
#      - Одолжить книгу
#      - Вернуть книгу
#      - Список доступных книг
#      - Выйти из программы

# %%
class Book:
    def __init__(self, title: str, author: str, isbn: str):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.is_borrowed = False


class Library:
    def __init__(self):
        self.books = []


    def add_book(self, book: Book):
        self.books.append(book)
        print(f'Книга "{book.title}" добавлена в библиотеку.')


    def borrow_book(self, isbn: str):
        book = self.find_book(isbn)
        if book is None:
            print("Книга не найдена.")
        elif book.is_borrowed:
            print("Книга уже взята.")
        else:
            book.is_borrowed = True
            print(f'Вы взяли книгу "{book.title}".')


    def return_book(self, isbn: str):
        book = self.find_book(isbn)
        if book is None:
            print("Книга не найдена.")
        elif not book.is_borrowed:
            print("Книга не была взята.")
        else:
            book.is_borrowed = False
            print(f'Вы вернули книгу "{book.title}".')


    def list_available_books(self):
        available_books = [book for book in self.books if not book.is_borrowed]
        if available_books:
            print("Доступные книги:")
            for book in available_books:
                print(f'- {book.title} (ISBN: {book.isbn})')
        else:
            print("Нет доступных книг.")


    def find_book(self, isbn: str):
        for book in self.books:
            if book.isbn == isbn:
                return book
        return None


def main():
    library = Library()
    while True:
        print("Меню:")
        print("1. Добавить книгу")
        print("2. Одолжить книгу")
        print("3. Вернуть книгу")
        print("4. Список доступных книг")
        print("5. Выйти")

        choice = input("Выберите действие (1-5): ")

        if choice == '1':
            title = input("Введите название книги: ")
            author = input("Введите автора книги: ")
            isbn = input("Введите ISBN книги: ")
            book = Book(title, author, isbn)
            library.add_book(book)
        elif choice == '2':
            isbn = input("Введите ISBN книги для заимствования: ")
            library.borrow_book(isbn)
        elif choice == '3':
            isbn = input("Введите ISBN книги для возврата: ")
            library.return_book(isbn)
        elif choice == '4':
            library.list_available_books()
        elif choice == '5':
            print("Выход из программы.")
            break
        else:
            print("Неверный выбор. Пожалуйста, попробуйте снова.")


if __name__ == "__main__":
    main()
# Out:
# Меню:
# 1. Добавить книгу
# 2. Одолжить книгу
# 3. Вернуть книгу
# 4. Список доступных книг
# 5. Выйти
# Выберите действие (1-5): 4
# Нет доступных книг.
#
# Меню:
# 1. Добавить книгу
# 2. Одолжить книгу
# 3. Вернуть книгу
# 4. Список доступных книг
# 5. Выйти
# Выберите действие (1-5): 1
# Введите название книги: Гарри Потер
# Введите автора книги: Д. Роулинг
# Введите ISBN книги: 116481415645164
# Книга "Гарри Потер" добавлена в библиотеку.
#
# Меню:
# 1. Добавить книгу
# 2. Одолжить книгу
# 3. Вернуть книгу
# 4. Список доступных книг
# 5. Выйти
# Выберите действие (1-5): 2
# Введите ISBN книги для заимствования: 116481415645164
# Вы взяли книгу "Гарри Потер".
#
# Меню:
# 1. Добавить книгу
# 2. Одолжить книгу
# 3. Вернуть книгу
# 4. Список доступных книг
# 5. Выйти
# Выберите действие (1-5): 2
# Введите ISBN книги для заимствования: 116481415645164
# Книга уже взята.
#
# Меню:
# 1. Добавить книгу
# 2. Одолжить книгу
# 3. Вернуть книгу
# 4. Список доступных книг
# 5. Выйти
# ...
